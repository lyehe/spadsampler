# %%
from lazyimread import predict_dimension_order
import numpy as np

predict_dimension_order(np.zeros((56, 100, 100, 31)))
# Out:
# 'TXYC'

# %%
data = np.random.randint(0, 256, (100, 100, 3), dtype=np.uint8)
np.mean(data, axis=(0, 1), keepdims=True).shape

# %%
a = tuple(i for i in range(1, 10))

# %%
data = np.random.randint(0, 256, (100, 100, 3), dtype=np.uint8)
p = np.ones_like(data) * 0.5
p = p.mean(axis=(0, 1), keepdims=True)
binomial_sample = np.random.binomial(data, p)

print(data.shape, p.shape, binomial_sample.shape)
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2)
ax[0].imshow(data)
ax[1].imshow(binomial_sample)

# %%
import tqdm as tqdm
import time

a = tqdm.tqdm(range(100), desc="Processing", leave=False, unit="p", unit_scale=True)
for i in a:
    a.set_description_str(f"Processing {i}")
    time.sleep(0.1)

# %%
from main import sample_data
import numpy as np

data = np.random.randint(0, 256, (40, 500, 500, 5), dtype=np.uint8)
output =sample_data(data)
# Out:
# Sampling P0d12500: 100%|██████████| 5/5 [00:06<00:00,  1.22s/it]

# %%
from main import imshow_pairs

imshow_pairs(data, output["P0d12500"][0])

# %%
a = dict(a=1, b=2, c=3)
a.items()
# Out:
# dict_items([('a', 1), ('b', 2), ('c', 3)])
