# %%
# %pip install git+https://github.com/lyehe/spadsampler.git
# %cd spadsampler

# %%
# examples
import numpy as np
from src.spadsampler import sample_data, imshow_pairs, SamplingMethod

data = np.random.randint(0, 256, (40, 128, 128, 5), dtype=np.uint8)
output, _ = sample_data(data, range=(-6, -3))
output.update({"data": data})
imshow_pairs(output)

output_b, _ = sample_data(data, range=(-6, -3), sampling_method=SamplingMethod.BERNOULLI)
output_b.update({"data": data})
imshow_pairs(output_b)
# Out:
# Sampling P0d06250: 100%|██████████| 3/3 [00:00<00:00, 12.67it/s]
# Sampling P0d06250: 100%|██████████| 3/3 [00:00<00:00, 12.50it/s]

# %%
from src.spadsampler import plot_histogram

# plot histogram
plot_histogram(data)

# visual inspection to scale down the data
plot_histogram(data, scale=0.89)
